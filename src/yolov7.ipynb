# %%
# %cd .
# !git clone https://github.com/WongKinYiu/yolov7.git     
# %cd yolov7
# %pip install -r requirements.txt      
# !wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7.pt

# %%
# %cd ../yolov7
# Out:
# c:\Users\kevin\Desktop\inmind\Final Project\yolov7
# C:\Users\kevin\AppData\Roaming\Python\Python311\site-packages\IPython\core\magics\osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %% [markdown]
# # Training and Testing

# %%
# !python train.py --img-size 640 --cfg cfg/training/yolov7.yaml --hyp data/hyp.scratch.custom.yaml --batch 4 --epochs 100 --data data/bmw_data.yaml --weights yolov7.pt --workers 24 --name yolo_bmw_det
# Out:
# ^C
# YOLOR  2024-3-13 torch 2.1.2+cu118 CUDA:0 (NVIDIA GeForce RTX 2060, 6143.6875MB)
#
# Namespace(weights='yolov7.pt', cfg='cfg/training/yolov7.yaml', data='data/bmw_data.yaml', hyp='data/hyp.scratch.custom.yaml', epochs=100, batch_size=8, img_size=[640, 640], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='', multi_scale=False, single_cls=False, adam=False, sync_bn=False, local_rank=-1, workers=24, project='runs/train', entity=None, name='yolo_bmw_det', exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias='latest', freeze=[0], v5_metric=False, world_size=1, global_rank=-1, save_dir='runs\\train\\yolo_bmw_det2', total_batch_size=8)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %% [markdown]
# To run inferences (predict on test images)

# %%
# !python detect.py --source ../BMW_dataset/images/test/ --weights runs/train/yolo_bmw_det3/weights/best.pt --conf 0.5 --name yolo_bmw_det3
# Out:
# Namespace(weights=['runs/train/yolo_bmw_det3/weights/best.pt'], source='../BMW_dataset/images/test/', img_size=640, conf_thres=0.5, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='yolo_bmw_det3', exist_ok=False, no_trace=False)
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# 13 dollys, 1 jack, Done. (42.1ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\yolo_bmw_det33\0.jpg
# 1 dolly, 1 jack, Done. (14.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\yolo_bmw_det33\1.jpg
# Done. (13.7ms) Inference, (0.0ms) NMS
#  The image with the result is saved in: runs\detect\yolo_bmw_det33\10.jpg
# ...

# %%
# !python test.py --weights runs/train/yolo_bmw_det3/weights/best.pt --data bmw_data.yaml --task test --name yolo_det3
# Out:
# Namespace(weights=['runs/train/yolo_bmw_det3/weights/best.pt'], data='.\\data\\bmw_data.yaml', batch_size=32, img_size=640, conf_thres=0.001, iou_thres=0.65, task='test', device='', single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project='runs/test', name='yolo_det3', exist_ok=False, no_trace=False, v5_metric=False)
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
#                  all         958        6673       0.665       0.553       0.524       0.378
#                dolly         958        3899       0.721       0.776       0.677       0.525
#                  bin         958         999       0.594       0.511        0.49       0.383
#                 jack         958        1775       0.682       0.373       0.405       0.225
# ...

# %% [markdown]
# # Creating ONNX inference

# %%
# !python export.py --weights runs/train/yolo_bmw_det3/weights/best.pt --grid --end2end --simplify --topk-all 100 --iou-thres 0.65 --conf-thres 0.35 --img-size 640 640 --max-wh 640
# Out:
# Namespace(weights='runs/train/yolo_bmw_det3/weights/best.pt', img_size=[640, 640], batch_size=1, dynamic=False, dynamic_batch=False, grid=True, end2end=True, max_wh=640, topk_all=100, iou_thres=0.65, conf_thres=0.35, device='cpu', simplify=True, include_nms=False, fp16=False, int8=False)
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
#
# Starting TorchScript export with torch 2.1.2+cu118...
# TorchScript export success, saved as runs/train/yolo_bmw_det3/weights/best.torchscript.pt
#
# Starting CoreML export with coremltools 7.1...
# CoreML export failure: The updates tensor should have shape [1, 3, 80, 80, 8]. Got (1, 3, 80, 80, 2)
#
# Starting TorchScript-Lite export with torch 2.1.2+cu118...
# TorchScript-Lite export success, saved as runs/train/yolo_bmw_det3/weights/best.torchscript.ptl
#
# Starting ONNX export with onnx 1.15.0...
# onnxruntime
# Simplifier failure: No module named 'onnxsim'
# ...
